# %% [markdown]
# # Test 1: Histograms
# Test my histogram plot.

# %% [markdown]
# ## 1. Import Packages

# %%
# The Python Standard Library

# The Third-Party Library
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# My Packages

# increase figure showing resolution
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 2. [numpy.histogram](https://numpy.org/doc/stable/reference/generated/numpy.histogram.html)

# %%
np.histogram([1, 2, 1], bins=[0, 1, 2, 3])
# Out:
# (array([0, 2, 1]), array([0, 1, 2, 3]))

# %%
np.histogram(np.arange(4), bins=np.arange(5), density=True)
# Out:
# (array([0.25, 0.25, 0.25, 0.25]), array([0, 1, 2, 3, 4]))

# %%
np.histogram([[1, 2, 1], [1, 0, 1]], bins=[0,1,2,3])
# Out:
# (array([1, 4, 1]), array([0, 1, 2, 3]))

# %%
a = np.arange(5)
hist, bin_edges = np.histogram(a, density=True)
hist
# Out:
# array([0.5, 0. , 0.5, 0. , 0. , 0.5, 0. , 0.5, 0. , 0.5])

# %%
bin_edges
# Out:
# array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ])

# %%
hist.sum()
# Out:
# 2.4999999999999996

# %%
np.sum(hist * np.diff(bin_edges))
# Out:
# 1.0

# %% [markdown]
# ## 3. [matplotlib: Histograms](https://matplotlib.org/3.5.0/gallery/statistics/hist.html)

# %%
# Create a random number generator with a fixed seed for reproducibility
rng = np.random.default_rng(19680801)
rng
# Out:
# Generator(PCG64) at 0x7FB5ED762C70

# %%
N_points = 100000
n_bins = 20

# Generate two normal distributions
dist1 = rng.standard_normal(N_points)
dist2 = 0.4 * rng.standard_normal(N_points) + 5

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(dist1, bins=n_bins)
axs[1].hist(dist2, bins=n_bins)
# Out:
# (array([2.0000e+00, 2.1000e+01, 5.1000e+01, 2.3500e+02, 7.8100e+02,
#         2.1000e+03, 4.5730e+03, 8.3390e+03, 1.2758e+04, 1.6363e+04,
#         1.7345e+04, 1.4923e+04, 1.0920e+04, 6.4830e+03, 3.1070e+03,
#         1.3810e+03, 4.5300e+02, 1.2200e+02, 3.6000e+01, 7.0000e+00]),
#  array([3.20889223, 3.38336526, 3.55783829, 3.73231132, 3.90678435,
#         4.08125738, 4.25573041, 4.43020344, 4.60467647, 4.7791495 ,
#         4.95362253, 5.12809556, 5.30256859, 5.47704162, 5.65151465,
#         5.82598768, 6.00046071, 6.17493374, 6.34940677, 6.5238798 ,
#         6.69835283]),
#  <BarContainer object of 20 artists>)

# %%
dist1
# Out:
# array([-0.98584721,  0.05040332,  0.96828412, ..., -0.0276232 ,
#         1.18599853,  0.48812025])

# %%
binning = np.linspace(-5, 5, 21)
np.histogram(dist1, bins=binning)
# Out:
# (array([    1,     3,    16,   109,   457,  1633,  4391,  9152, 14954,
#         19228, 19052, 15101,  9246,  4388,  1635,   505,   110,    15,
#             3,     1]),
#  array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#          0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ]))

# %%
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

binning1 = np.linspace(np.min(dist1), np.max(dist1), 21)
binning2 = np.linspace(np.min(dist2), np.max(dist2), 21)
hist1 = np.histogram(dist1, bins=binning1)
hist2 = np.histogram(dist2, bins=binning2)

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(dist1, bins=binning1)
axs[1].hist(dist2, bins=binning2)
# Out:
# (array([2.0000e+00, 2.1000e+01, 5.1000e+01, 2.3500e+02, 7.8100e+02,
#         2.1000e+03, 4.5730e+03, 8.3390e+03, 1.2758e+04, 1.6363e+04,
#         1.7345e+04, 1.4923e+04, 1.0920e+04, 6.4830e+03, 3.1070e+03,
#         1.3810e+03, 4.5300e+02, 1.2200e+02, 3.6000e+01, 7.0000e+00]),
#  array([3.20889223, 3.38336526, 3.55783829, 3.73231132, 3.90678435,
#         4.08125738, 4.25573041, 4.43020344, 4.60467647, 4.7791495 ,
#         4.95362253, 5.12809556, 5.30256859, 5.47704162, 5.65151465,
#         5.82598768, 6.00046071, 6.17493374, 6.34940677, 6.5238798 ,
#         6.69835283]),
#  <BarContainer object of 20 artists>)

# %%
hist2
# Out:
# (array([    2,    21,    51,   235,   781,  2100,  4573,  8339, 12758,
#         16363, 17345, 14923, 10920,  6483,  3107,  1381,   453,   122,
#            36,     7]),
#  array([3.20889223, 3.38336526, 3.55783829, 3.73231132, 3.90678435,
#         4.08125738, 4.25573041, 4.43020344, 4.60467647, 4.7791495 ,
#         4.95362253, 5.12809556, 5.30256859, 5.47704162, 5.65151465,
#         5.82598768, 6.00046071, 6.17493374, 6.34940677, 6.5238798 ,
#         6.69835283]))

# %%
binning2
# Out:
# array([3.20889223, 3.38336526, 3.55783829, 3.73231132, 3.90678435,
#        4.08125738, 4.25573041, 4.43020344, 4.60467647, 4.7791495 ,
#        4.95362253, 5.12809556, 5.30256859, 5.47704162, 5.65151465,
#        5.82598768, 6.00046071, 6.17493374, 6.34940677, 6.5238798 ,
#        6.69835283])
